# %% [markdown]
# ### Imports

# %%
import gurobipy as gp
import pandas as pd

# %% [markdown]
# ### Functions

# %%
def extract(data, row, fact, maximize=True):
    text = str(data.iloc[row][fact]).strip("mg%?")
    if str(text) == "nan" or len(text) == 0:
        return maximize * 1_000_000
    return float(text)

# %% [markdown]
# ### File Input

# %%
df = pd.read_excel("Nutritional Facts.xlsx", index_col=0)

# %% [markdown]
# ### Restaurant / Category Selection

# %%
res = ""
cat = ""
real_meal = True
cat_limit = False
subset = df
if res != "":
    subset = subset[subset["Restaurant"] == res]
elif cat != "":
    subset = subset[subset["Category"] == cat]
if real_meal and not cat_limit:
    bad_cats = ["Drinks", "Beverages", "Sauces and Condiments", "Coffee", "Salad Dressing"
                "Ocean Water", "Iced Teas", "Limeades", "Soft Drinks", ]
    subset = subset[~subset["Category"].isin(bad_cats)]
subset  # Contains all food entries
# Out:
#      Restaurant     Category                                         Food  \
# 0        Arby's   Sandwiches                                  Arby's Melt
# 1        Arby's   Sandwiches                              Arby-Q Sandwich
# 2        Arby's   Sandwiches                      Beef 'n Cheddar Classic
# 3        Arby's   Sandwiches                  Beer Battered Fish Sandwich
# 4        Arby's   Sandwiches              Buffalo Crispy Chicken Sandwich
# ...         ...          ...                                          ...
# 5948    Zaxby's  Zappetizers                                Fried Pickles
# 5949    Zaxby's  Zappetizers  Fried White Cheddar Bites w/ Marinara Sauce
# 5950    Zaxby's  Zappetizers                                  Onion Rings
# 5951    Zaxby's  Zappetizers                        Spicy Fried Mushrooms
# 5952    Zaxby's  Zappetizers                                  Tater Chips
#
#      Serving Size Calories From Fat Calories Total Fat Saturated Fat  \
# 0            146g               110      330       12g          4.0g
# 1            182g               100      400       11g          3.5g
# 2      1 sandwich               180      450       20g            6g
# 3      1 sandwich               210      600       23g            4g
# 4      1 sandwich               210      500       23g          4.5g
# ...           ...               ...      ...       ...           ...
# 5948            ?               610      860       69g          9.5g
# 5949            ?               260      470       29g         11.0g
# 5950            ?               350      500       40g          5.5g
# 5951            ?               420      620       48g          6.5g
# 5952            ?               620      940       69g          9.5g
#
#      Trans Fat Cholesterol  ... Protein Total Fat % Saturated Fat %  \
# 0          .5g        35mg  ...     18g         18%             20%
# 1          .5g        30mg  ...     18g         17%             18%
# 2           1g        50mg  ...     23g         31%             30%
# 3           0g        65mg  ...     25g         35%             20%
# 4         0.0g        55mg  ...     24g         35%             23%
# ...        ...         ...  ...     ...         ...             ...
# 5948         ?        20mg  ...      7g        106%             48%
# 5949         ?        45mg  ...     16g         45%             55%
# 5950         ?        15mg  ...      5g         62%             28%
# 5951         ?        15mg  ...      8g         74%             33%
# 5952         ?        22mg  ...      9g        106%             48%
#
#      Cholesterol % Sodium % Total Carbohydrates % Dietary Fiber % Protein %  \
# 0              12%      39%                   13%              8%       36%
# 1              10%      52%                   19%             12%       36%
# 2              17%      53%                   15%              8%       46%
# 3              22%      76%                   24%             20%       50%
# 4              18%      78%                   16%             16%       48%
# ...            ...      ...                   ...             ...       ...
# 5948            7%     130%                   18%             16%       14%
# 5949           15%      40%                   13%              4%       32%
# 5950            5%      44%                   11%              8%       10%
# 5951            5%      58%                   14%             20%       16%
# 5952            7%      80%                   24%             32%       18%
#
#      Vitamin A %                                                URL
# 0             2%     https://fastfoodnutrition.org/arbys/arbys-melt
# 1             4%  https://fastfoodnutrition.org/arbys/arby-q-san...
# 2             2%  https://fastfoodnutrition.org/arbys/beef-n-che...
# 3            NaN  https://fastfoodnutrition.org/arbys/beer-batte...
# 4            NaN  https://fastfoodnutrition.org/arbys/buttermilk...
# ...          ...                                                ...
# 5948         NaN  https://fastfoodnutrition.org/zaxbys/fried-pic...
# 5949         NaN  https://fastfoodnutrition.org/zaxbys/fried-whi...
# 5950         NaN   https://fastfoodnutrition.org/zaxbys/onion-rings
# 5951         NaN  https://fastfoodnutrition.org/zaxbys/spicy-fri...
# 5952         NaN   https://fastfoodnutrition.org/zaxbys/tater-chips
#
# [5045 rows x 24 columns]

# %% [markdown]
# ### Sample Constraint Setting

# %%
requirements = {"Protein": 100, "Dietary Fiber": 45, "Vitamin A %": 15}

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### Model & Variables

# %%
m = gp.Model()
xis = [m.addVar(vtype=gp.GRB.BINARY) for _ in subset.index]  # GRB.BINARY / GRB.INTEGER

# %% [markdown]
# #### Constraints

# %%
for fact, req in requirements.items():  # Nutrition Requirements
    print(f"Constraining {fact} >= {req}")
    m.addConstr(sum((x * extract(subset, r, fact, maximize=False) for r, x in enumerate(xis))) >= req)

if real_meal:
    for i, food in enumerate(subset.iloc):  # Excludes zero calorie (from fat) entries
        m.addConstr(xis[i] <= extract(subset, i, "Calories From Fat", maximize=True))
# Out:
# Constraining Protein >= 100
# Constraining Dietary Fiber >= 45
# Constraining Vitamin A % >= 15

# %% [markdown]
# #### Objective

# %%
m.ModelSense = gp.GRB.MINIMIZE
m.setObjective(sum((x * extract(subset, r, "Calories From Fat", maximize=True) for r, x in enumerate(xis))))

# %% [markdown]
# ### Solving

# %%
m.optimize()
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 5048 rows, 5045 columns and 14860 nonzeros
# Model fingerprint: 0xdb94bfd7
# Variable types: 0 continuous, 5045 integer (5045 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+06]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# Found heuristic solution: objective 2025.0000000
# Presolve removed 5045 rows and 1329 columns
# Presolve time: 0.23s
# Presolved: 3 rows, 3716 columns, 8177 nonzeros
# Variable types: 0 continuous, 3716 integer (3216 binary)
#
# Root relaxation: objective 4.857627e+01, 2 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   48.57627    0    2 2025.00000   48.57627  97.6%     -    0s
# H    0     0                    1064.0000000   48.57627  95.4%     -    0s
# H    0     0                      51.0000000   48.57627  4.75%     -    0s
#      0     0   49.10000    0    2   51.00000   49.10000  3.73%     -    0s
#      0     0   49.10000    0    2   51.00000   49.10000  3.73%     -    0s
#      0     0   51.00000    0    2   51.00000   51.00000  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#   RLT: 1
#
# Explored 1 nodes (8 simplex iterations) in 1.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 51 1064 2025
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.100000000000e+01, best bound 5.100000000000e+01, gap 0.0000%

# %% [markdown]
# ### Optimal Objective

# %%
print(m.ObjVal, "calories from fat")
m.printAttr('X')
best_choices = [i for i, x in enumerate(xis) if x.x > 0]
# Out:
# 51.0 calories from fat
#
#     Variable            X
# -------------------------
#        C1115            1
#        C1124            1
#        C1965            1
#        C1979            1
#        C2935            1
#        C2968            1
#        C4386            1

# %% [markdown]
# ### Corresponding Meal(s)

# %%
print(subset.iloc[best_choices]["Food"], ":")
subset = subset.iloc[best_choices]
subset = subset[subset["Protein"] > '0g']
subset = subset[subset["Dietary Fiber"] > '0g']
subset
# Out:
# 1391                       Black Beans
# 1400                       Pinto Beans
# 2289                       Plain Bagel
# 2303                    English Muffin
# 3349                         Baked Cod
# 3430                      Baked Potato
# 5055    Fresh Fit Crispy Chicken Salad
# Name: Food, dtype: object :
#               Restaurant             Category                            Food  \
# 1391            Chipotle  Extras and Toppings                     Black Beans
# 1400            Chipotle  Extras and Toppings                     Pinto Beans
# 2289       Dunkin Donuts               Bagels                     Plain Bagel
# 2303       Dunkin Donuts     Bakery Favorites                  English Muffin
# 3430  Long John Silver's                Sides                    Baked Potato
# 5055              Subway               Salads  Fresh Fit Crispy Chicken Salad
#
#      Serving Size Calories From Fat Calories Total Fat Saturated Fat  \
# 1391         4 oz                 9      120        1g          0.0g
# 1400         4 oz                 9      120        1g          0.0g
# 2289            ?                 5      310        1g          0.0g
# 2303            ?                 5      140        1g          0.0g
# 3430      1 piece                 3      297        0g          0.0g
# 5055      1 salad                15      460       20g            2g
#
#      Trans Fat Cholesterol  ... Protein Total Fat % Saturated Fat %  \
# 1391      0.0g         0mg  ...      7g          2%              0%
# 1400      0.0g         5mg  ...      7g          2%              0%
# 2289      0.0g         0mg  ...     11g          2%              0%
# 2303      0.0g         0mg  ...      4g          2%              0%
# 3430      0.0g         0mg  ...      6g          0%              0%
# 5055        0g       100mg  ...     41g         31%             10%
#
#      Cholesterol % Sodium % Total Carbohydrates % Dietary Fiber % Protein %  \
# 1391            0%      10%                    8%             44%       14%
# 1400            2%      14%                    7%             40%       14%
# 2289            0%      26%                   21%             16%       22%
# 2303            0%       5%                   10%             24%        8%
# 3430            0%      15%                   22%             32%       12%
# 5055           33%      60%                   11%             32%       82%
#
#      Vitamin A %                                                URL
# 1391          2%  https://fastfoodnutrition.org/chipotle/black-b...
# 1400          2%  https://fastfoodnutrition.org/chipotle/pinto-b...
# 2289          0%  https://fastfoodnutrition.org/dunkin-donuts/pl...
# 2303          0%  https://fastfoodnutrition.org/dunkin-donuts/en...
# 3430          0%  https://fastfoodnutrition.org/long-john-silver...
# 5055         60%  https://fastfoodnutrition.org/subway/fresh-fit...
#
# [6 rows x 24 columns]
